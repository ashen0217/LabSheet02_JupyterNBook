# %%
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_csv("Airdata.csv",header=None)

# %%
store_data.shape
# Out:
# (8785, 8)

# %%
store_data.head()
# Out:
#                0            1         2           3               4  \
# 0       DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction
# 1  1/1/2020 0:00    2.1805286        87    1.484318        75.96376
# 2  1/1/2020 1:00    1.4905287        89   2.7416782       113.19859
# 3  1/1/2020 2:00    1.6905286        85    3.563818             135
# 4  1/1/2020 3:00    1.4305286        84   2.8116899       129.80557
#
#                 5               6               7
# 0  NO2_Location_A  NO2_Location_B  NO2_Location_C
# 1           39.23           52.88           62.37
# 2            38.3           44.95           52.53
# 3             NaN            48.4            54.8
# 4           37.28           47.18            50.8

# %%
display(store_data)
# Out:
#                      0            1         2           3               4  \
# 0             DateTime  Temperature  Humidity  Wind_Speed  Wind_Direction
# 1        1/1/2020 0:00    2.1805286        87    1.484318        75.96376
# 2        1/1/2020 1:00    1.4905287        89   2.7416782       113.19859
# 3        1/1/2020 2:00    1.6905286        85    3.563818             135
# 4        1/1/2020 3:00    1.4305286        84   2.8116899       129.80557
# ...                ...          ...       ...         ...             ...
# 8780  12/31/2020 19:00    4.9205284        72   4.5536795       251.56506
# 8781  12/31/2020 20:00    4.9905286        74   3.2599385        186.3402
# 8782  12/31/2020 21:00    4.3605285        84   10.587917       252.18112
# 8783  12/31/2020 22:00    3.8205285        88    8.435069       219.80557
# 8784  12/31/2020 23:00    3.1705287        89    6.792466       212.00539
#
#                    5               6               7
# ...

# %%
records = []
for i in range(1,8785):
    records.append([str(store_data.values[i,j]) for j in range(0,7)])

# %% [markdown]
# records

# %%
records
# Out:
# [['1/1/2020 0:00',
#   '2.1805286',
#   '87',
#   '1.484318',
#   '75.96376',
#   '39.23',
#   '52.88'],
#  ['1/1/2020 1:00',
#   '1.4905287',
#   '89',
#   '2.7416782',
#   '113.19859',
#   '38.3',
#   '44.95'],
#  ['1/1/2020 2:00', '1.6905286', '85', '3.563818', '135', 'nan', '48.4'],
#  ['1/1/2020 3:00',
#   '1.4305286',
#   '84',
#   '2.8116899',
#   '129.80557',
#   '37.28',
#   '47.18'],
#  ['1/1/2020 4:00', '0.84052867', '86', '1.8', '126.869896', '29.97', '41.48'],
#  ['1/1/2020 5:00', '1.1605287', '80', '3.0547013', '135', '30.35', '43.18'],
#  ['1/1/2020 6:00', '1.6805286', '72', '4.072935', '135', '32.18', '38.8'],
#  ['1/1/2020 7:00',
#   '1.7005286',
#   '71',
#   '5.3999996',
#   '126.869896',
#   'nan',
#   '40.95'],
#  ['1/1/2020 8:00', '1.3005286', '73', '5.00128', '120.25643', '37', '42.75'],
#  ['1/1/2020 9:00',
#   '0.41052866',
#   '80',
#   '2.968636',
#   '104.03624',
#   '37.2',
#   '43.65'],
#  ['1/1/2020 10:00',
#   '-0.30947134',
#   '86',
#   '2.5959969',
# ...

# %%
movie_data = pd.read_csv("movie_dataset.csv",header=None)

# %%
movie_data.head()
# Out:
#               0         1                   2                          3   \
# 0   The Revenant  13 Hours              Allied                   Zootopia
# 1         Beirut   Martian             Get Out                        NaN
# 2       Deadpool       NaN                 NaN                        NaN
# 3          X-Men    Allied                 NaN                        NaN
# 4  Ninja Turtles     Moana  Ghost in the Shell  Ralph Breaks the Internet
#
#           4         5       6                 7             8          9   \
# 0     Jigsaw  Achorman  Grinch  Fast and Furious  Ghostbusters  Wolverine
# 1        NaN       NaN     NaN               NaN           NaN        NaN
# 2        NaN       NaN     NaN               NaN           NaN        NaN
# 3        NaN       NaN     NaN               NaN           NaN        NaN
# 4  John Wick       NaN     NaN               NaN           NaN        NaN
#
#         10         11          12                 13             14  \
# ...

# %%
movie_data.shape
# Out:
# (7501, 20)

# %%
records=[]
for x in range(0,7501):
    records.append([str(movie_data.values[x,y])for y in range(0,20)])

# %%
records
# Out:
# [['The Revenant',
#   '13 Hours',
#   'Allied',
#   'Zootopia',
#   'Jigsaw',
#   'Achorman',
#   'Grinch',
#   'Fast and Furious',
#   'Ghostbusters',
#   'Wolverine',
#   'Mad Max',
#   'John Wick',
#   'La La Land',
#   'The Good Dunosaur',
#   'Ninja Turtles',
#   'The Good Dunosaur Bad Moms',
#   '2 Guns',
#   'Inside Out',
#   'Valerian',
#   'Spiderman 3'],
#  ['Beirut',
#   'Martian',
#   'Get Out',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['Deadpool',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['X-Men',
#   'Allied',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
association_rules = apriori(
    records,
    min_support=0.01,
    min_confidence=0.5,
    min_lift=1.0,
    max_length=2
)

# %%
results = list(association_rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'nan'}), support=0.9998666844420744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9998666844420744, lift=1.0)]),
#  RelationRecord(items=frozenset({'Ant Man', 'nan'}), support=0.010798560191974404, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ant Man'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'Aquaman', 'nan'}), support=0.014264764698040262, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aquaman'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'Avengers', 'nan'}), support=0.011465137981602452, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avengers'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
# ...
